# %%
import pandas as pd

# نام فایل CSV خود را در اینجا قرار دهید
# اگر فایل در پوشه دیگری است، آدرس کامل آن را بنویسید
# مثال: 'C:/Users/YourUser/Documents/data.csv'
file_path = 'output_tab.csv'

try:
    # خواندن فایل CSV به یک دیتافریم (DataFrame) پانداز
    # با توجه به مشکل قبلی، بهتر است انکدینگ را مشخص کنیم
    df = pd.read_csv(file_path, encoding='utf-8-sig')

    # --- چاپ محتوای دیتافریم ---

    # 1. چاپ ۵ سطر اول (برای بررسی سریع فایل‌های بزرگ)
    print("--- نمایش ۵ سطر اول فایل (head) ---")
    print(df.head())

    # 2. چاپ کل دیتافریم (برای فایل‌های کوچک)
    # اگر فایل شما خیلی بزرگ است، این خط را کامنت کنید تا ترمینال شلوغ نشود
    # print("\n--- نمایش کل محتوای فایل ---")
    # print(df)

    # 3. نمایش اطلاعات کلی در مورد دیتافریم (تعداد سطرها، ستون‌ها و نوع داده‌ها)
    print("\n--- اطلاعات کلی دیتافریم (info) ---")
    df.info()


except FileNotFoundError:
    print(f"خطا: فایل '{file_path}' پیدا نشد. لطفاً مسیر و نام فایل را بررسی کنید.")
except Exception as e:
    print(f"یک خطا در هنگام خواندن فایل رخ داد: {e}")
    print("نکته: مطمئن شوید که فایل CSV شما فرمت درستی دارد و انکدینگ آن صحیح است.")
# Out:
# --- نمایش ۵ سطر اول فایل (head) ---
#   abstract                                               body category  \
# 0      NaN  به گزارش «تابناک ورزشی»، دومین روز از هفته پنج...    ورزشی
# 1      NaN  به گزارش «تابناک»، نورنیوز با انتشار یادداشتی ...    سیاسی
# 2      NaN  به گزارش «تابناک»، احمدی میدری، وزیر تعاون، کا...  اقتصادی
# 3      NaN  به گزارش «تابناک» به نقل از فارس، «مسعود پزشکی...   فرهنگی
# 4      NaN  انس جهانی طلا در رکوردزنی تاریخی با افزایش ۴۴ ...  اقتصادی
#
#   date_georgian_iso     link  \
# 0        2024-09-22  1261014
# 1        2024-09-22  1261020
# 2        2024-09-22  1261022
# 3        2024-09-22  1261024
# 4        2024-09-23  1261208
#
#                                                title
# 0                         جدول لیگ برتر در هفته پنجم
# 1    پشت پرده حملات تروریستی اسرائیل و انفجار پیجرها
# 2          تکلیف متناسب‌سازی حقوق بازنشستگان مشخص شد
# 3                ناگفته‌هایی از حضور پزشکیان در جبهه
# 4  لرزه تصمیم آمریکایی‌ها بر بازار طلا و سکه تهرا...
#
# --- اطلاعات کلی دیتافریم (info) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abstract           1 non-null      object
#  1   body               396 non-null    object
#  2   category           477 non-null    object
#  3   date_georgian_iso  477 non-null    object
#  4   link               477 non-null    int64
#  5   title              477 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 22.5+ KB
