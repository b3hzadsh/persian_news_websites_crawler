# %%
import pandas as pd

# نام فایل CSV خود را در اینجا قرار دهید
# اگر فایل در پوشه دیگری است، آدرس کامل آن را بنویسید
# مثال: 'C:/Users/YourUser/Documents/data.csv'
file_path = 'output_tabnak_longer.csv'


try:
    # خواندن فایل CSV به یک دیتافریم (DataFrame) پانداز
    # با توجه به مشکل قبلی، بهتر است انکدینگ را مشخص کنیم
    df = pd.read_csv(file_path, encoding='utf-8-sig')
    # شمارش تعداد هر نوع خبر در ستون category
    category_counts = df['category'].value_counts()

    print("\nتعداد خبرها در هر دسته:")
    print(category_counts)

    # --- چاپ محتوای دیتافریم ---

    # 1. چاپ ۵ سطر اول (برای بررسی سریع فایل‌های بزرگ)
    print("--- نمایش ۵ سطر اول فایل (head) ---")
    print(df.tail())

    # 2. چاپ کل دیتافریم (برای فایل‌های کوچک)
    # اگر فایل شما خیلی بزرگ است، این خط را کامنت کنید تا ترمینال شلوغ نشود
    # print("\n--- نمایش کل محتوای فایل ---")
    # print(df)

    # 3. نمایش اطلاعات کلی در مورد دیتافریم (تعداد سطرها، ستون‌ها و نوع داده‌ها)
    print("\n--- اطلاعات کلی دیتافریم (info) ---")
    df.info()


except FileNotFoundError:
    print(f"خطا: فایل '{file_path}' پیدا نشد. لطفاً مسیر و نام فایل را بررسی کنید.")
except Exception as e:
    print(f"یک خطا در هنگام خواندن فایل رخ داد: {e}")
    print("نکته: مطمئن شوید که فایل CSV شما فرمت درستی دارد و انکدینگ آن صحیح است.")
# Out:
# تعداد خبرها در هر دسته:
# category
# اقتصادی    15580
# ورزشی      14379
# فرهنگی      1484
# سیاسی        389
# Name: count, dtype: int64
# --- نمایش ۵ سطر اول فایل (head) ---
#                                                     body category  \
# 31827  مبارز ایرانی مقابل حریف روس خود با عملکردی ضعی...    ورزشی
# 31828  بلال ماخوف از سوی آژانس مبارزه با دوپینگ ۴ سال...    ورزشی
# 31829  موفقیت دراگان اسکوچیچ سرمربی تیم ملی فوتبال ای...    ورزشی
# 31830  با اعلام وزارت ورزش و جوانان، اعضاء جدید هيات ...    ورزشی
# 31831  تیم ملی فوتسال ایران در یک نبرد پرگل و مهیج و ...    ورزشی
#
#       date_georgian_iso     link
# 31827        2021-09-24  1078176
# 31828        2021-09-24  1078177
# 31829        2021-09-24  1078180
# 31830        2021-09-24  1078188
# 31831        2021-09-24  1078181
#
# --- اطلاعات کلی دیتافریم (info) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31832 entries, 0 to 31831
# Data columns (total 4 columns):
# ...
